# %%
import os
import numpy as np
import pandas as pd

# main plotting packages
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load the data
csv_path = os.path.join('example_datasets', "cars_dataset.csv",)
cars = pd.read_csv(csv_path)

# view the data
cars
# Out:
#            Make            Model  Origin  Year   MPG  Cylinders  Displacement  \
# 0     Chevrolet  Chevelle Malibu      US    70  18.0          8         307.0
# 1         Buick      Skylark 320      US    70  15.0          8         350.0
# 2      Plymouth        Satellite      US    70  18.0          8         318.0
# 3           AMC        Rebel SST      US    70  16.0          8         304.0
# 4          Ford           Torino      US    70  17.0          8         302.0
# ..          ...              ...     ...   ...   ...        ...           ...
# 401        Ford       Mustang GL      US    82  27.0          4         140.0
# 402  Volkswagen           Pickup  Europe    82  44.0          4          97.0
# 403       Dodge          Rampage      US    82  32.0          4         135.0
# 404        Ford           Ranger      US    82  28.0          4         120.0
# 405       Chevy             S-10      US    82  31.0          4         119.0
#
#      Horsepower  Weight  Acceleration
# 0           130    3504          12.0
# 1           165    3693          11.5
# 2           150    3436          11.0
# 3           150    3433          12.0
# 4           140    3449          10.5
# ..          ...     ...           ...
# 401          86    2790          15.6
# 402          52    2130          24.6
# 403          84    2295          11.6
# 404          79    2625          18.6
# 405          82    2720          19.4
#
# [406 rows x 10 columns]

# %%
sns.countplot(x='Make', data = cars.loc[cars["Origin"]=="Japan"])

# %%
# Load the brain networks dataset, select subset, and collapse the multi-index
df = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)

used_networks = [1, 5, 6, 7, 8, 12, 13, 17]
used_columns = (df.columns
                  .get_level_values("network")
                  .astype(int)
                  .isin(used_networks))
df = df.loc[:, used_columns]

df.columns = df.columns.map("-".join)

# Compute a correlation matrix and convert to long-form
corr_mat = df.corr().stack().reset_index(name="correlation")

# %%
corr_mat
# Out:
#       level_0  level_1  correlation
# 0      1-1-lh   1-1-lh     1.000000
# 1      1-1-lh   1-1-rh     0.881516
# 2      1-1-lh   5-1-lh     0.431619
# 3      1-1-lh   5-1-rh     0.418708
# 4      1-1-lh   6-1-lh    -0.084634
# ...       ...      ...          ...
# 1439  17-4-lh  17-2-lh     0.517481
# 1440  17-4-lh  17-2-rh     0.256544
# 1441  17-4-lh  17-3-lh     0.264381
# 1442  17-4-lh  17-3-rh     0.090302
# 1443  17-4-lh  17-4-lh     1.000000
#
# [1444 rows x 3 columns]

# %%
df
# Out:
#          1-1-lh     1-1-rh     5-1-lh     5-1-rh     6-1-lh     6-1-rh  \
# 0     56.055744  92.031036 -35.898861  -1.889181   5.898688 -43.692322
# 1     55.547253  43.690075  19.568010  15.902983 -23.231823 -10.745867
# 2     60.997768  63.438793  19.247454  37.209419   2.392153  16.509109
# 3     18.514868  12.657158  32.896915  11.199619 -14.665752   2.073715
